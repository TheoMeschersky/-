# %% [markdown]
# # Консультация к контрольной, 2025

# %% [markdown]
# ## Задание 1: Веб-скрейпинг
#
# Напишите скрипт, который получает текстовое описание мема про Сызрань с сайта memexpert (https://memexpert.net/ru/seychas-by-v-syzran). Сохраните текст в файл meme.txt.

# %%
import requests
from pprint import pprint
from bs4 import BeautifulSoup

# %%
syzran = requests.get("https://memexpert.net/ru/seychas-by-v-syzran")

# %%
syzran #Проверка
# Out:
# <Response [200]>

# %%
soup_syzran = BeautifulSoup(syzran.text, 'html.parser')
soup_syzran
# Out:
# <!DOCTYPE html>
#
# <html lang="ru" prefix="og: http://ogp.me/ns# video: http://ogp.me/ns/video#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <style type="text/css">
#     *, ::before, ::after {
#   --tw-border-spacing-x: 0;
#   --tw-border-spacing-y: 0;
#   --tw-translate-x: 0;
#   --tw-translate-y: 0;
#   --tw-rotate: 0;
#   --tw-skew-x: 0;
#   --tw-skew-y: 0;
#   --tw-scale-x: 1;
#   --tw-scale-y: 1;
#   --tw-pan-x:  ;
#   --tw-pan-y:  ;
#   --tw-pinch-zoom:  ;
#   --tw-scroll-snap-strictness: proximity;
#   --tw-gradient-from-position:  ;
#   --tw-gradient-via-position:  ;
#   --tw-gradient-to-position:  ;
#   --tw-ordinal:  ;
#   --tw-slashed-zero:  ;
#   --tw-numeric-figure:  ;
#   --tw-numeric-spacing:  ;
#   --tw-numeric-fraction:  ;
#   --tw-ring-inset:  ;
#   --tw-ring-offset-width: 0px;
#   --tw-ring-offset-color: #fff;
#   --tw-ring-color: rgb(59 130 246 / 0.5);
#   --tw-ring-offset-shadow: 0 0 #0000;
# ...

# %%
flagbearers = soup_syzran.find_all('p', {'class':"text-gray-900 dark:text-gray-100"})
flagbearers = flagbearers[0].text.replace('\n', '').replace('            ','')



with open('meme6.txt','w',encoding='utf-8') as file:
    file.write(soup_syzran.find_all('p', {'class':"text-gray-900 dark:text-gray-100"})[0].get_text().replace('\n', '').replace('            ','').replace('    ','') +'\n')
    file.write(soup_syzran.find_all('p', {'class':"text-gray-900 dark:text-gray-100"})[1].get_text().replace('\n', '').replace('            ','').replace('    ',''))

# %% [markdown]
# ## Задание 2: Предобработка
#
# - Прочитайте текст из файла meme.txt.
# - Создайте список слов из текста (приведите к нижнему регистру, удалите знаки препинания по краям слов).
# - Используя list comprehension, создайте список, содержащий длины каждого слова.Постройте гистограмму распределения длин слов.
# - Используя словарь, посчитайте частотность первых букв всех слов в сказке. Выведите 3 самые частые буквы.
#
# ВоПрОсИкИ:
# Чем my_list.append(x) отличается от my_list += [x]? А от my_list.extend([x])?

# %%
with open('meme6.txt','r',encoding='utf-8') as file:
  raw = file.read()

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation

nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
raw_nltk = [word.lower().strip(punctuation) for word in raw.split()]
raw_nltk = [word for word in raw_nltk if word != '']
raw_nltk
# Out:
# ['на',
#  'картинке',
#  'изображена',
#  'женщина',
#  'одетая',
#  'в',
#  'старинную',
#  'одежду',
#  'которая',
#  'держит',
#  'большую',
#  'рыбу',
#  'выражение',
#  'лица',
#  'женщины',
#  'говорит',
#  'о',
#  'том',
#  'что',
#  'она',
#  'устала',
#  'и',
#  'недовольна',
#  'текст',
#  'на',
#  'изображении',
#  'добавляет',
#  'комичности',
#  'ситуации',
#  'описывая',
#  'рутинные',
#  'дела',
#  'и',
#  'ощущение',
#  'что',
#  'она',
#  'живет',
#  'не',
#  'своей',
#  'жизнью',
#  'мем',
#  'выражает',
#  'чувство',
#  'усталости',
#  'от',
#  'повседневных',
#  'обязанностей',
#  'и',
#  'желание',
#  'отдохнуть',
#  'сейчас',
#  'бы',
#  'в',
#  'сызрань',
#  'и',
#  'полы',
#  'помыть',
#  'рыба',
#  'ещё',
#  'эта',
#  'но',
#  'надо',
#  'рыбу',
#  'выгулять',
#  'я',
#  'будто',
#  'не',
#  'свою',
#  'жизнь',
#  'живу',
#  'как-то',
#  'всё',
#  'я',
#  'не',
#  'знаю']

# %% [markdown]
# ## Задание 3: Лингвистический анализ с spaCy
#
# Загрузите модель ru_core_news_sm для spaCy. Обработайте текст сказки.
# - Для каждого предложения выведите его номер и леммы всех существительных и глаголов в нем, а также все глаголы настоящего времени.
# - Найдите и выведите все именованные сущности (doc.ents).
# - Посчитайте, каких частей речи больше всего в тексте.
# - Для каждого предложения выведите его текст и вершину (head).

# %% [markdown]
# ## Задание 4: Работа с базами данных
#
# Создайте БД meme.db с двумя таблицами и запоните её. Схема БД:
#
# - sentences (id, text, num_tokens)
# - words (id, sentence_id, word, lemma, pos)
#
# Напишите SQL-запрос, который:
# - находит топ-5 самых частых лемм (сортировка по убыванию).
# - для каждого предложения выводит его текст и распределение слов по частям речи.
#
# ВоПрОсИкИ:
# - Чем WHERE отличается от HAVING?
# - Почему мы разделили данные на две таблицы?
